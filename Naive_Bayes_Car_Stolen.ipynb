# %% [markdown]
# <a href="https://colab.research.google.com/github/MANMOHAN04/ML/blob/main/Naive_Bayes_Car_Stolen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Car.csv')
df
# Out:
#     Color    Type    Origin Stolen
# 0     Red  Sports  Domestic    Yes
# 1     Red  Sports  Domestic     No
# 2     Red  Sports  Domestic    Yes
# 3  Yellow  Sports  Domestic     No
# 4  Yellow  Sports  Imported    Yes
# 5  Yellow     SUV  Imported     No
# 6  Yellow     SUV  Imported    Yes
# 7  Yellow     SUV  Domestic     No
# 8     Red     SUV  Imported     No
# 9     Red  Sports  Imported    Yes

# %%
# problem
# Colour =Red, type=SUV, Origin=Domestic
# Find probability of a car stolen or not stolen

# %%
#P(Yes / Red,SUV,Domestic) = P(Red/Yes)* P(SUV/Yes)* P(Domestic/Yes)* P(Yes)

#P(No / Red,SUV,Domestic) = P(Red/No)* P(SUV/No)* P(Domestic/No)* P(No)

#Compare and decide using the Maximum a posteriori rule

# %%
df['Stolen'].value_counts()
# Out:
# Yes    5
# No     5
# Name: Stolen, dtype: int64

# %%
py=5/10  #py means probability of yes
py
# Out:
# 0.5

# %%
pn = 1-py
pn
# Out:
# 0.5

# %%
#Color
pd.crosstab(df['Color'],df['Stolen'])
# Out:
# Stolen  No  Yes
# Color
# Red      2    3
# Yellow   3    2

# %%
PRNo=2/5
PYNo=3/5

PRYes =3/5
PYYes = 2/5

# %%
pd.crosstab(df['Type'],df['Stolen'])
# Out:
# Stolen  No  Yes
# Type
# SUV      3    1
# Sports   2    4

# %%
PSUV_No = 3/5
PSports_No = 2/5

PSUV_Yes = 1/5
PSports_Yes = 4/5

# %%
#
pd.crosstab(df['Origin'],df['Stolen'])
# Out:
# Stolen    No  Yes
# Origin
# Domestic   3    2
# Imported   2    3

# %%
PD_No = 3/5
PI_No = 2/5

PD_Yes = 2/5
PD_Yes = 3/5

# %%
PYes = py*PRYes*PSUV_Yes*PD_Yes
PYes
# Out:
# 0.036

# %%
PNo = pn*PRNo*PSUV_No*PD_No
PNo
# Out:
# 0.072
