# %% [markdown]
# <a href="https://colab.research.google.com/github/MANMOHAN04/ML/blob/main/Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/play_tennis.csv')
df.head(5)
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
df.drop(columns=['day'],inplace = True)

# %%
# problem 1
# outlook =Sunny, temp=Hot, humidity=High, wind=Weak
#Play or not play

# %%
#Solution
#P(Yes / Sunny,Hot,High,wind) = P(Sunny/Yes)* P(Hot/Yes)* P(High/Yes)* P(Weak/Yes)* P(Yes)

#P(No / Sunny,Hot,High,wind) = P(Sunny/No)* P(Hot/No)* P(High/No)* P(Weak/No)* P(No)

#Compare and decide using the Maximum a posteriori rule

# %%
#Training

#LookUp Table

#Testing

# %%
df['play'].value_counts()
# Out:
# Yes    9
# No     5
# Name: play, dtype: int64

# %%
py=9/14
py
# Out:
# 0.6428571428571429

# %%
pn=5/14
pn
# Out:
# 0.35714285714285715

# %%
#outlook
pd.crosstab(df['outlook'],df['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
PONo=0
PRNo=2/5
PSNo=3/5

POYes=4/9
PRYes =3/9
PSYes = 2/9

# %%
#temp
pd.crosstab(df['temp'],df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
PCoolNo = 1/5
PHotNo = 2/5
PMildNo = 2/5

PCoolYes =3/9
PHotYes = 2/9
PMildYes = 4/9

# %%
#humidity
pd.crosstab(df['humidity'],df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
PHighNo = 4/5
PNormal = 1/5

PHighYes = 3/9
PNormalYes =6/9

# %%
#wind
pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
PStrongNo = 3/5
PWeakNo = 2/5

PStrongYes = 3/9
PWeakYes = 6/9

# %%
# outlook =Sunny, temp=Hot, humidity=High, wind=Weak

PYes = py*PSYes*PHotYes*PHighYes*PWeakYes
PYes
# Out:
# 0.007054673721340388

# %%
# outlook =Sunny, temp=Hot, humidity=High, wind=Weak

PNo = pn*PSNo*PHotNo*PHighNo*PWeakNo
PNo
# Out:
# 0.02742857142857143
